# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = sum((y - yp)**2) / len(y)
    return mse

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squar error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squar error is 184.818
# The Mean absolute error is 10.721

# %%
1.https://www.kaggle.com/russellyates88/suicide-rates-overview-1985-to-2016
    (1)這組資料之所以會重要是因為這可以為社會經濟學上的預防自殺的貢獻
    (2)作者透過各國政府內的所有自殺比率來做為資料來源
    (3)GDP、自殺率及年齡
    (4)透過各國間的數據比對來評估之間的影響
2.如何規劃整體的分析/解決方案
    (1)該透過什麼樣的數據分析比對來改善這問題提出的業績?
    (2)資料該藉由客群心得、問卷調查來進行量化比較
    (3)量化後的滿意度及統計後的改進方向
    (4)透過比對過往或網路上相關資訊來看看是否有符合過去研究，若符合則以此為借鏡修正。如若不然則再自行透過一次次改變變因來改善此狀況。
# Out:
#   File "<ipython-input-14-8e6b1be82c61>", line 1
#     1.https://www.kaggle.com/russellyates88/suicide-rates-overview-1985-to-2016
#           ^
# SyntaxError: invalid syntax
